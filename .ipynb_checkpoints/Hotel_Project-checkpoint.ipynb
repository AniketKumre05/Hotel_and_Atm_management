# %%
class Hotel:
    def welcome(self,Obj):
        print(">>>>> Welcome to the Taj Lake Hotel <<<<<")
        m=Obj.getMenu()
        m.getMenu(Obj)
    
    
class menu:
    
        def getMenu(self,Obj):
            flag=True
            while flag:
                print("1 for Snacks")
                print("2 for Veg")
                print("3 for Non-Veg")
                print("4 for Desserts")
                print("5 for Exit")
                option=int(input("Enter the your choice:"))
                if(option==1):
                    Obj.getMenuPrint().Snacks(Obj)
                    option=int(input("Select Snacks item:"))
                    if(option==1):
                        print(Obj.getDishName().getSamosa(Obj),"=",Obj.getPrice().getssprice(Obj))
                        qty=int(input("Enter the quantity of Samosa:"))
                        print("The Quantity of the Samosa is",Obj.getCount().getsscount(qty))
                        Obj.getBill().updateBill(Obj.getPrice().getssprice(Obj),qty)
                        
                            
                    
                    elif(option==2):
                        print(Obj.getDishName().getKachori(Obj),"=",Obj.getPrice().getkkprice(Obj))
                        qty=int(input("Enter the quantity of Kachori:"))
                        print("The Quantity of the Kachori is",Obj.getCount().getkkcount(qty))
                        Obj.getBill().updateBill(Obj.getPrice().getkkprice(Obj),qty)
                    
                elif(option==2):
                    Obj.getMenuPrint().Veg(Obj)
                    option=int(input("Select the Veg item:"))
                    if(option==1):
                        print(Obj.getDishName().getPaneer(Obj),"=",Obj.getPrice().getppprice(Obj))
                        qty=int(input("Enter the quantity of Paneer:"))
                        print("The Quantity of the Paneer is",Obj.getCount().getppcount(qty))
                        Obj.getBill().updateBill(Obj.getPrice().getppprice(Obj),qty)
                
                    elif(option==2):
                        print(Obj.getDishName().getBhature(Obj),"=",Obj.getPrice().getcbprice(Obj))
                        qty=int(input("Enter the quantity of Chhole Bhature:"))
                        print("The Quantity of the Chhole Bhature is",Obj.getCount().getcbcount(qty))
                        Obj.getBill().updateBill(Obj.getPrice().getcbprice(Obj),qty)
                        
                elif(option==3):
                    Obj.getMenuPrint().NonVeg(Obj)
                    option=int(input("Select the Non-Veg item:"))
                    if(option==1):
                        print(Obj.getDishName().getChilli(Obj),"=",Obj.getPrice().getccprice(Obj))
                        qty=int(input("Enter the quantity of Chilli Chicken:"))
                        print("The Quantity of the Chilli Chicken is",Obj.getCount().getcccount(qty))
                        Obj.getBill().updateBill(Obj.getPrice().getccprice(Obj),qty)
                
                    elif(option==2):
                        print(Obj.getDishName().getBiryani(Obj),"=",Obj.getPrice().getbbprice(Obj))
                        qty=int(input("Enter the quantity of Chicken Biryani:"))
                        print("The Quantity of the Chicken Biryani is",Obj.getCount().getbbcount(qty))
                        print(Obj.getBill().updateBill(Obj.getPrice().getbbprice(Obj),qty))
                        
                        
                elif(option==4):
                    Obj.getMenuPrint().Desserts(Obj)
                    option=int(input("Select the Desserts item:"))
                    if(option==1):
                        print(Obj.getDishName().getMalai(Obj),"=",Obj.getPrice().getrmprice(Obj))
                        qty=int(input("Enter the quantity of Ras Malai:"))
                        print("The Quantity of the Ras Malai is",Obj.getCount().getrmcount(qty))
                        Obj.getBill().updateBill(Obj.getPrice().getrmprice(Obj),qty)
                
                    elif(option==2):
                        print(Obj.getDishName().getJamun(Obj),"=",Obj.getPrice().getgmprice(Obj))
                        qty=int(input("Enter the quantity of Gulab Jamun:"))
                        print("The Quantity of the Gulab Jamun is",Obj.getCount().getgmcount(qty))
                        print(Obj.getBill().updateBill(Obj.getPrice().getgmprice(Obj),qty))
                        
                        
                elif(option==5):
                    print("Your total Bill is",Obj.getBill().getBill())
                    dis=Obj.getDiscount().getDisc(Obj)
                    Obj.getFB().getDetails(qty,Obj)
                    print("[[[  Thank you for Visiting our Hotel  ]]]") 
                    flag=False
                        
            
                         
    
class menuPrint:
    def Snacks(self,Obj):
        print("\n<<<<< SNACKS >>>>>\n")
        print("1 for Samosa")
        print("2 for Kachori")
    def Veg(self,Obj):
        print("\n<<<<< VEG >>>>>\n")
        print("1 for Palak Paneer")
        print("2 for Chhole Bhature")
    def NonVeg(self,Obj):
        print("\n<<<<< NON-VEG >>>>>")
        print("1 for Chilli Chicken")
        print("2 for Chicken Biryani")
    def Desserts(self,Obj):
        print("\n<<<<< DESSERTS >>>>>\n")
        print("1 for Ras Malai")
        print("2 for Gulab Jamun")
        

    
class dishName:
    ss="Samosa"
    kk="Kachori"
    pp="Palak Paneer"
    cb="Chhole Bhature"
    cc="Chilli Chicken"
    bb="Chicken Biryani"
    rm="Ras Malai"
    gm="Gulab Jamun"
    def getSamosa(self,Obj):
        return self.ss
    def getKachori(self,Obj):
        return self.kk
    def getPaneer(self,Obj):
        return self.pp
    def getBhature(self,Obj):
        return self.cb
    def getChilli(self,Obj):
        return self.cc
    def getBiryani(self,Obj):
        return self.bb
    def getMalai(self,Obj):
        return self.rm
    def getJamun(self,Obj):
        return self.gm
    
    
class price:
    ss=35
    kk=30
    pp=300
    cb=230
    cc=400
    bb=450
    rm=40
    gm=30
    def getssprice(self,Obj):
        return self.ss
    def getkkprice(self,Obj):
        return self.kk
    def getppprice(self,Obj):
        return self.pp
    def getcbprice(self,Obj):
        return self.cb
    def getccprice(self,Obj):
        return self.cc
    def getbbprice(self,Obj):
        return self.bb
    def getrmprice(self,Obj):
        return self.rm
    def getgmprice(self,Obj):
        return self.gm
    
class count:
    sscount=0
    def getsscount(self, qty):
        self.sscount=self.sscount+qty
        return self.sscount
    def getsamosacount(self):
        return self.sscount
    
    kkcount=0
    def getkkcount(self,qty):
        self.kkcount=self.kkcount+qty
        return self.kkcount
    def getkachoricount(self):
        return self.kkcount
    
    ppcount=0
    def getppcount(self,qty):
        self.ppcount=self.ppcount+qty
        return self.ppcount
    def getpaneercount(self):
        return self.ppcount
    
    cbcount=0
    def getcbcount(self,qty):
        self.cbcount=self.cbcount+qty
        return self.cbcount
    def getbhaturecount(self):
        return self.cbcount
    
    cccount=0
    def getcccount(self,qty):
        self.cccount=self.cccount+qty
        return self.cccount
    def getchickencount(self):
        return self.cccount
    
    bbcount=0
    def getbbcount(self,qty):
        self.bbcount=self.bbcount+qty
        return self.bbcount
    def getbiryanicount(self):
        return self.bbcount
    
    rmcount=0
    def getrmcount(self,qty):
        self.rmcount=self.rmcount+qty
        return self.rmcount
    def getmalaicount(self):
        return self.rmcount
    
    gmcount=0
    def getgmcount(self,qty):
        self.gmcount=self.gmcount+qty
        return self.gmcount
    def getjamuncount(self):
        return self.gmcount
    
    
class Bill:
    bill=0
    def updateBill(self,qty,amt):
        self.bill=self.bill+amt*qty
        print("Current Bill is",self.bill)
    def getBill(self):
        return self.bill
    
class Discount:
    FinalBill=0
    def getDisc(self,Obj):
        day=input("Enter Day:")
        if(day=="Wednesday"):
            bal=Obj.getBill().getBill()
            disc=bal*(18/100)
            print("Discount Amount is",disc)
            self.FinalBill=bal-disc
            print("Final Bill is:",self.FinalBill)
        elif(day=="Monday"):
            bal=Obj.getBill().getBill()
            disc=bal*(20/100)
            print("Discount Amount is",disc)
            self.FinalBill=bal-disc
            print("Final Bill is:",self.FinalBill)
        
    def getFBill(self):
        return self.FinalBill
            
class PrintBill:
    def getDetails(self,qty,Obj):
        sc=Obj.getCount().getsamosacount()
        sn=Obj.getDishName().getSamosa(Obj)
        sp=Obj.getPrice().getssprice(Obj)
        kc=Obj.getCount().getkachoricount()
        kn=Obj.getDishName().getKachori(Obj)
        kp=Obj.getPrice().getkkprice(Obj)
        pc=Obj.getCount().getpaneercount()
        pn=Obj.getDishName().getPaneer(Obj)
        pp=Obj.getPrice().getppprice(Obj)
        bc=Obj.getCount().getbhaturecount()
        bn=Obj.getDishName().getBhature(Obj)
        bp=Obj.getPrice().getcbprice(Obj)
        cc=Obj.getCount().getchickencount()
        cn=Obj.getDishName().getChilli(Obj)
        cp=Obj.getPrice().getccprice(Obj)
        br=Obj.getCount().getbiryanicount()
        brn=Obj.getDishName().getBiryani(Obj)
        brp=Obj.getPrice().getbbprice(Obj)
        mc=Obj.getCount().getmalaicount()
        mn=Obj.getDishName().getMalai(Obj)
        mp=Obj.getPrice().getrmprice(Obj)
        jc=Obj.getCount().getjamuncount()
        jn=Obj.getDishName().getJamun(Obj)
        jp=Obj.getPrice().getgmprice(Obj)
        
        
        print("DishName   DishPrice   Qty   Total\n")   
        if(sc>0):
            print(sn,sp,sc,sp*sc)
        if(kc>0):
            print(kn,"     ",kp,"   *   ",kc,"    ",kp*kc)
        if(pc>0):
            print(pn,"      ",pp,"   *   ",pc,"    ",pp*pc)
        if(bc>0):
            print(bn,"      ",bp,"   *   ",bc,"    ",bp*bc)
        if(cc>0):
            print(cn,"      ",cp,"   *   ",cc,"    ",cp*cc)
        if(br>0):
            print(brn,"      ",brp,"   *   ",br,"    ",brp*br)
        if(mc>0):
            print(mn,"      ",mp,"   *   ",mc,"    ",mp*mc)
        if(jc>0):
            print(jn,"      ",jp,"   *   ",jc,"    ",jp*jc)
        print("Total                            =",Obj.getDiscount().getFBill())
            

            

    
    
    
    
class ObjFact:
    h=Hotel()
    m=menu()
    mp=menuPrint()
    dn=dishName()
    p=price()
    c=count()
    d=Discount()
    b=Bill()
    fb=PrintBill()
    def getHotel(self):
        return self.h
    def getMenu(self):
        return self.m
    def getMenuPrint(self):
        return self.mp
    def getDishName(self):
        return self.dn
    def getPrice(self):
        return self.p
    def getCount(self):
        return self.c
    def getDiscount(self):
        return self.d
    def getBill(self):
        return self.b
    def getFB(self):
        return self.fb
    
Obj=ObjFact()
s=Obj.getHotel().welcome(Obj)
# Out:
# >>>>> Welcome to the Taj Lake Hotel <<<<<
# 1 for Snacks
# 2 for Veg
# 3 for Non-Veg
# 4 for Desserts
# 5 for Exit
# Enter the your choice:1
#
# <<<<< SNACKS >>>>>
#
# 1 for Samosa
# 2 for Kachori
# Select Snacks item:1
# Samosa = 35
# Enter the quantity of Samosa:2
# The Quantity of the Samosa is 2
# Current Bill is 70
# 1 for Snacks
# 2 for Veg
# 3 for Non-Veg
# 4 for Desserts
# 5 for Exit
# Enter the your choice:5
# Your total Bill is 70
# Enter Day:Monday
# Discount Amount is 14.0
# Final Bill is: 56.0
# DishName   DishPrice   Qty   Total
#
# Samosa 35 2 70
# Total                            = 56.0
# [[[  Thank you for Visiting our Hotel  ]]]

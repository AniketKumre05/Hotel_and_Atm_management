# %%
class Welcome:
    def ATM(self,Obj):
        print(">>>>>    Welcome to the Central Bank ATM     <<<<<\n")
        Obj.getAuth().checkpin(Obj)
    
class pin:
    pin=2321
    def getPin(self):
        return self.pin
    
    
class Authenticate:
    def checkpin(self,Obj):
        cp=int(input("Enter your ATM Pin:"))
        if(cp==Obj.getpin().getPin()):
            Obj.getMenu().printMenu(Obj)
        else:
            print("You entered wrong pin")
            print("You have only last 3 attempt")
            Obj.getBlock().getCorrect(Obj)
            

class Block:
    def getCorrect(self,Obj):
        attempt=1
        flag=True
        while(attempt<=3):
            print("Enter pin again")
            cp=int(input())
            if(cp==Obj.getpin().getPin()):
                print("You entered correct pin")
                Obj.getMenu().printMenu(Obj)
                break
            else:
                attempt = attempt + 1
            
        print("Your card is block")
            
        
        
    
class Menu:
    def printMenu(self,Obj):
        print("1 for Balance Inquery")
        print("2 for Deposit Money")
        print("3 for Withdraw Money")
        print("4 for Ledger")
        print("5 for Change PIN")
        opt=int(input("Select your option:"))
        if(opt==1):
            Obj.getHandler().getBal(Obj)
            
        
    
class Handler:
    def getBal(self,Obj):
        print("Your balance is",Obj.getBalance().printBal(Obj)
        
 

class Balance:
    bal=10000
    def printBal(self,Obj):
        return self.bal
    
class ObjFact:
    wl=Welcome()
    p=pin()
    a=Authenticate()
    bl=Block()
    m=Menu()
    h=Handler()
    b=Balance()
    d=Deposit()
    #w=Withdraw()
    #l=Ledger()
    #pc=Pinchange()
    def getWelcome(self):
        return self.wl
    def getpin(self):
        return self.p
    def getAuth(self):
        return self.a
    def getBlock(self):
        return self.bl
    def getMenu(self):
        return self.m
    def getHandler(self):
        return self.h
    def getBalance(self):
        return self.b
    def getDeposit(self):      
        return self.d
   # def getWithdraw(self):
   #     return self.w
   # def getLedger(self):
   #     return self.l
   # def getPinchange(self):
   #     return self.pc
    
    
Obj=ObjFact()
s=Obj.getWelcome().ATM(Obj)
# Out:
#   Input In [7]
#     class Balance:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##

# %%
class Welcome:
    def ATM(self,Obj):
        print(">>>>>    Welcome to the Central Bank ATM     <<<<<\n")
        Obj.getAuth().checkpin(Obj)
class pin:
    pin=7888
    def getPin(self):
        return self.pin
    def changepin(self):
        oldpin=int(input("Enter your old pin:"))
        if(oldpin==self.pin):
            changepin=int(input("Enter new pin:"))
            self.pin=changepin
            return self.pin
    
class Authenticate:
    def checkpin(self,Obj):
        cp=int(input("Enter your ATM Pin:"))
        if(cp==Obj.getpin().getPin()):
            Obj.getMenu().printMenu(Obj)
        else:
            print("You entered wrong pin")
            print("You have only last 3 attempt")
            Obj.getBlock().getCorrect(Obj)
            
class Block:
    def getCorrect(self,Obj):
        attempt=1
        flag=True
        while(attempt<=3):
            print("Enter pin again")
            cp=int(input())
            if(cp==Obj.getpin().getPin()):
                print("You entered correct pin")
                Obj.getMenu().printMenu(Obj)
                break
            else:
                attempt = attempt + 1 
        print("Your card is block")
            
    
class Menu:
    def printMenu(self,Obj):
        flag=True
        while(flag):
            print("1 for Balance Inquery")
            print("2 for Deposit Money")
            print("3 for Withdraw Money")
            print("4 for Change PIN")
            print("5 for Exit")
            opt=int(input("Select your option:"))
            if(opt==1):
                Obj.getHandler().getBal(Obj)
            elif(opt==2):
                Obj.getDeposit().getDeposit(Obj)
            elif(opt==3):
                Obj.getWithdraw().getWithdraw()
            elif(opt==4):
                Obj.getpin().changepin()
                print("Your has been changed")
            elif(opt==5):
                print("Thank you for visiting ATM")
                flag=False
            
class Handler:
    def getBal(self,Obj):
        print("Your balance is",Obj.getBalance().printBal())
    
class Balance:
    bal = 10000
    def printBal(self):
        return self.bal
    
class Deposit:
    def getDeposit(self,Obj):
        amt=int(input("Enter amount"))
        print("Your amount after transaction is",Obj.getLedger().updateDepo(amt))
        
class Withdraw:
    def getWithdraw(self):
        amt=int(input("Enter amount:"))
        print("Your amount after transaction is",Obj.getLedger().updateWithdraw(amt))
        
        
    
class Ledger:
    bal=10000
    def printBal(self):
        bal=Obj.getBalance().printBal()
        return self.bal
    def updateDepo(self,amt):
        self.bal=self.bal+amt
        return self.bal
    def updateWithdraw(self,amt):
        self.bal=self.bal-amt
        return self.bal
        
    
    
class ObjFact:
    wl=Welcome()
    p=pin()
    a=Authenticate()
    bl=Block()
    m=Menu()
    h=Handler()
    b=Balance()
    d=Deposit()
    w=Withdraw()
    l=Ledger()
    def getWelcome(self):
        return self.wl
    def getpin(self):
        return self.p
    def getAuth(self):
        return self.a
    def getBlock(self):
        return self.bl
    def getMenu(self):
        return self.m
    def getHandler(self):
        return self.h
    def getBalance(self):
        return self.b
    def getDeposit(self):      
        return self.d
    def getWithdraw(self):
        return self.w
    def getLedger(self):
        return self.l
    
Obj=ObjFact()
s=Obj.getWelcome().ATM(Obj)
# Out:
# >>>>>    Welcome to the Central Bank ATM     <<<<<
#
# Enter your ATM Pin:33
# You entered wrong pin
# You have only last 3 attempt
# Enter pin again
# 7888
# You entered correct pin
# 1 for Balance Inquery
# 2 for Deposit Money
# 3 for Withdraw Money
# 4 for Change PIN
# 5 for Exit
# Select your option:5
# Thank you for visiting ATM
# Your card is block

# %% [markdown]
# ##
